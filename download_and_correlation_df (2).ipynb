# %% [markdown]
# <a href="https://colab.research.google.com/github/marlapinkert/final_project_compcognition/blob/main/download_and_correlation_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A Random Forest Classifier for Autism Spectrum Disorder (ASD)
# #### Final Project for TEWA I, supervisors: Dominik Pegler, Mengfan Zhang, Jozsef Arato
# *Jannis Breßgott, Sara Binder, Marla Pinkert, 04.07.2024*
#
# Autism spectrum disorder (ASD) is a neurological and developmental disorder which manifests in differences in social communication and interaction, learning, and sensation, with a wide range of associated subjective and objective impairments of quality of life (for review, see Lord et al., 2020). As demonstrated by Ilioska and colleagues in a large scale analysis of resting-state fMRI data including 1824 individuals (796 with ASD), ASD is characterized by both hypo- and hyperconnectivity (Ilioska et al., 2023). Previous studies attempted to train machine learning models to predict ASD diagnosis based on structural and functional changes in the brain, and reached prediction accuracies of ? to ? (SOURCES).
#
# Subsequently, we decided to train a random forest model to predict subjects' ASD diagnosis based on functional connectivity, utilizing preprocessed data from the Autism Brain Imaging Data Exchange I (ABIDE I, Craddock et al., 2013). Thus, we had access to 883 subjects (??? with ASD). We downloaded timecourses preprocessed using the CPAC pipeline (as outlined in http://preprocessed-connectomes-project.org/abide/Pipelines.html), as it previously performed best in a similar classification attempt (SOURCE). Timecourses were extracted using the Craddock 200 (CC200) atlas (Craddock et al., 2011).

# %% [markdown]
# ## Import dependencies and download data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from itertools import combinations
from glob import glob
from nilearn import connectome
from nilearn import plotting
import networkx as nx
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA

# %%
# Below function can be used to download the ABIDE 
# !python resources/download_abide_preproc.py -d rois_cc200 -p cpac -s filt_global -o output
# Out:
# Downloading data for ASD and TDC participants
# No upper age threshold specified
# No lower age threshold specified
# No site specified, using all sites...
# No sex specified, using all sexes...
# b',Unnamed: 0,SUB_ID,X,subject,SITE_ID,FILE_ID,DX_GROUP,DSM_IV_TR,AGE_AT_SCAN,SEX,HANDEDNESS_CATEGORY,HANDEDNESS_SCORES,FIQ,VIQ,PIQ,FIQ_TEST_TYPE,VIQ_TEST_TYPE,PIQ_TEST_TYPE,ADI_R_SOCIAL_TOTAL_A,ADI_R_VERBAL_TOTAL_BV,ADI_RRB_TOTAL_C,ADI_R_ONSET_TOTAL_D,ADI_R_RSRCH_RELIABLE,ADOS_MODULE,ADOS_TOTAL,ADOS_COMM,ADOS_SOCIAL,ADOS_STEREO_BEHAV,ADOS_RSRCH_RELIABLE,ADOS_GOTHAM_SOCAFFECT,ADOS_GOTHAM_RRB,ADOS_GOTHAM_TOTAL,ADOS_GOTHAM_SEVERITY,SRS_VERSION,SRS_RAW_TOTAL,SRS_AWARENESS,SRS_COGNITION,SRS_COMMUNICATION,SRS_MOTIVATION,SRS_MANNERISMS,SCQ_TOTAL,AQ_TOTAL,COMORBIDITY,CURRENT_MED_STATUS,MEDICATION_NAME,OFF_STIMULANTS_AT_SCAN,VINELAND_RECEPTIVE_V_SCALED,VINELAND_EXPRESSIVE_V_SCALED,VINELAND_WRITTEN_V_SCALED,VINELAND_COMMUNICATION_STANDARD,VINELAND_PERSONAL_V_SCALED,VINELAND_DOMESTIC_V_SCALED,VINELAND_COMMUNITY_V_SCALED,VINELAND_DAILYLVNG_STANDARD,VINELAND_INTERPERSONAL_V_SCALED,VINELAND_PLAY_V_SCALED,VINELAND_COPING_V_SCALED,VINELAND_SOCIAL_STANDARD,VINELAND_SUM_SCORES,VINELAND_ABC_STANDARD,VINELAND_INFORMANT,WISC_IV_VCI,WISC_IV_PRI,WISC_IV_WMI,WISC_IV_PSI,WISC_IV_SIM_SCALED,WISC_IV_VOCAB_SCALED,WISC_IV_INFO_SCALED,WISC_IV_BLK_DSN_SCALED,WISC_IV_PIC_CON_SCALED,WISC_IV_MATRIX_SCALED,WISC_IV_DIGIT_SPAN_SCALED,WISC_IV_LET_NUM_SCALED,WISC_IV_CODING_SCALED,WISC_IV_SYM_SCALED,EYE_STATUS_AT_SCAN,AGE_AT_MPRAGE,BMI,anat_cnr,anat_efc,anat_fber,anat_fwhm,anat_qi1,anat_snr,func_efc,func_fber,func_fwhm,func_dvars,func_outlier,func_quality,func_mean_fd,func_num_fd,func_perc_fd,func_gsr,qc_rater_1,qc_notes_rater_1,qc_anat_rater_2,qc_anat_notes_rater_2,qc_func_rater_2,qc_func_notes_rater_2,qc_anat_rater_3,qc_anat_notes_rater_3,qc_func_rater_3,qc_func_notes_rater_3,SUB_IN_SMP\n'
# Collecting images of interest...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050004_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050005_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050006_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050007_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050008_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050009_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050010_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050011_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050012_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050014_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050015_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050016_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050020_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050022_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050023_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050024_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050025_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050027_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050029_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050030_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050031_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050032_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050033_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050034_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050035_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050036_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050037_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050038_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050040_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050041_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050042_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050044_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050045_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050046_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050047_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050048_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050050_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050051_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050052_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050055_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050056_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050057_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050058_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050059_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Pitt_0050060_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050102_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050104_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050105_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050107_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050111_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050112_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050113_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050114_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050115_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050116_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050117_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050118_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050119_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050121_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050122_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050125_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050127_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050128_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050129_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050130_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050131_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050132_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050133_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050134_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Olin_0050136_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050142_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050143_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050144_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050145_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050146_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050147_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050148_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050149_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050150_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050152_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050153_rois_cc200.1D to download queue...
# Error extracting info from phenotypic file, skipping...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050156_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050157_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050158_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050159_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050160_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050161_rois_cc200.1D to download queue...
# Error extracting info from phenotypic file, skipping...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050166_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050167_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050168_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050169_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050170_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/OHSU_0050171_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050182_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050183_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050184_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050186_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050187_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050188_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050189_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050190_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050191_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050193_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050194_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050195_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050196_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050197_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050198_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050199_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050200_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050201_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050203_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050204_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050205_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050206_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050207_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050208_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050209_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050210_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050211_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050212_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050213_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050214_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050215_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050216_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SDSU_0050217_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050232_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050233_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050234_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050235_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050236_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050237_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050239_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050240_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050241_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050243_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050245_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050246_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050247_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050248_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050249_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050250_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050251_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050252_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050253_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050254_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050255_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050257_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050259_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050260_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050261_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050262_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050263_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050264_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050266_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050267_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050268_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050269_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050270_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Trinity_0050271_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050272_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050273_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050274_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050275_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050276_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050277_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050278_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050280_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050282_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050283_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050284_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050285_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050287_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050289_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050290_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050291_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050292_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050293_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050294_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050295_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050297_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050298_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050300_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050301_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050302_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050307_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050310_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050314_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050315_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050318_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050319_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050320_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050321_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050324_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050325_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050326_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050327_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050329_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050330_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050331_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050332_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050334_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050335_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050336_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050337_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050338_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050339_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050340_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050341_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050342_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050343_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050344_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050345_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050346_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050347_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050348_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050349_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050350_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050351_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050352_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050353_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050355_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050356_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050357_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050358_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050360_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050361_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050362_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050363_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050364_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050365_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050366_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050367_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050368_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050369_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050370_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050372_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050373_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050374_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050375_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050377_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_1_0050379_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050382_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050385_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050386_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050387_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050388_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050390_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050391_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050397_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050399_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050402_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050404_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050405_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050406_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050407_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050408_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050410_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050411_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050412_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050413_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050414_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050415_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050416_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050417_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050418_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050419_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050421_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050424_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050425_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050426_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050427_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/UM_2_0050428_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050433_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050434_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050435_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050436_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050437_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050438_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050439_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050440_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050441_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050442_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050443_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050444_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050445_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050446_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050447_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050448_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050449_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050455_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050463_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050466_rois_cc200.1D to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/USM_0050467_rois_cc200.1D to download queue...
# ...
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051480_rois_cc200.1D
# 95.361991% percent complete
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051481_rois_cc200.1D
# 95.475113% percent complete
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051482_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051482_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051483_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051483_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051484_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051484_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051485_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051485_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051486_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051486_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051487_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051487_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051488_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051488_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051489_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051489_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051490_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051490_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051491_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051491_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051492_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051492_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/Caltech_0051493_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/Caltech_0051493_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051557_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051557_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051558_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051558_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051559_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051559_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051560_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051560_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051561_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051561_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051562_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051562_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051563_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051563_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051564_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051564_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051565_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051565_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051566_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051566_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051567_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051567_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051570_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051570_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051571_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051571_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051572_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051572_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051573_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051573_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051574_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051574_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051576_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051576_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051577_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051577_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051578_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051578_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051579_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051579_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051580_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051580_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051581_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051581_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051582_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051582_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051583_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051583_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051584_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051584_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/SBL_0051585_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/SBL_0051585_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051606_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051606_rois_cc200.1D.
#  Check input arguments and try again.
# Retrieving: C:\Users\marli\Documents\Studium\Master\2024 SoSe\TEWA I - Computational cognitive sciences\final_project\output\Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051607_rois_cc200.1D
# There was a problem downloading https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051607_rois_cc200.1D.
#  Check input arguments and try again.
# Done!

# %%
# We read in the phenotype dataframe and create a new df with only diagnoses
# The Phenotypic_V1_0b_preprocessed1.csv can be downloaded from http://preprocessed-connectomes-project.org/abide/download.html
pheno_df = pd.read_csv("Phenotypic_V1_0b_preprocessed1.csv", index_col = 0)
diagnose_df = pheno_df.loc[:,["FILE_ID", "DX_GROUP", "DSM_IV_TR"]]

# %%
# We list the paths for each subject using glob
subj_paths = sorted(glob("cpac/filt_global/rois_cc200/*.1D"))

# %% [markdown]
# ## Model 1: Functional Connectivity, all Predictors
#
# For our first model, we followed an approach already attempted by Chen et al. (2015), who trained a random forest classifier on the ABIDE data and utlized individual correlations between all ROIs as predictors without employing any kinds of dimensionality reduction techniques. Our procedure was the following:
# 1. Calculate connectivity matrices using 200 timcourses
# 2. Vectorize connectivity matrices while only keeping individual correlations
# 3. Repeat first two steps for all subjects to create a DataFrame with rows corresponding to subjects and columns to correlations

# %% [markdown]
# ### Prepare Data

# %%
# Define Class which gets dict of unique correlations for one subject
class UniqueCorrelations:
    '''
        Parameters:
            - time_course_path: path to a 1D file containing timecourses of all relevant regions
              for one specific subject
            - correlation_kind: {"covariance", "correlation", "partial correlation", "tangent", "precision"}, 
              default="correlation"
              Kind of correlation to calcualte, takes same arguments as nilearn.connectome.ConnectivityMeasure()
            - subject_ID: whether "FILE_ID" should be added to dict, default = True
    '''
    
    def __init__(self, correlation_kind, time_course_path, subject_ID=True):

        self.correlation_kind = correlation_kind
        self.time_course_path = time_course_path
        self.subject_ID = subject_ID
    
    def get_corr_list(self):
    
        '''          
        Creates: self.unique_corrs, self.connectivity_matrix
        - unique corrs: dictionnary with unique correlations between timecourses,
          keys corresponding to correlation of two timeseries 
          e.g.: key '0x4' corresponds to correlation of regions 0 and 4.
        - connectivity matrix: connectivity matrix for all timeseries for one subjects.
          can be used to be plotted with nilearn.plotting.plot_matrix()
        '''

        # read the file into a DataFrame
        df = pd.read_csv(self.time_course_path, sep="\t")
        df = np.array(df)
        
        # calculate corr matrix for DataFrame (all rois)
        correlation_measure = connectome.ConnectivityMeasure(
            kind=self.correlation_kind
        )
        
        connectivity_matrix = correlation_measure.fit_transform([df])[0]
        corrs = pd.DataFrame(connectivity_matrix)
    
        # create index with only unique combinations of row x column
        # this ensures we get an index which only gets us the "lower half"
        # of the correlation matrix
        rois_numbers = np.linspace(0, (len(corrs)-1), len(corrs), dtype = "int")
        comb_ind = [comb for comb in combinations(rois_numbers, 2)]
    
        # use new index to select only the unique combinations from our DataFrame
        # we save this as a dictionnary with the combination of values as keys
        # I.e., correlation of region 1 and region 4 is called "1x4"
        unique_corrs = {}
        for ind in comb_ind:
           unique_corrs[f"{ind[0]}x{ind[1]}"] = corrs.iloc[ind]
    
        # We add the name of the file as "ID" to the dictionnary. This allows us to later identify 
        # the subjects when we create our DataFrame with all our subjects
        subject_id = self.time_course_path.split("\\")[-1].split("_rois")[0]
        unique_corrs["FILE_ID"] = subject_id   

        self.unique_corrs = unique_corrs
        self.connectivity_matrix = connectivity_matrix

# %%
# Create DataFrame with all subjects
list_unique_corrs = []
for path in subj_paths:
    get_unique_corr = UniqueCorrelations("correlation", path)
    list_unique_corrs.append(get_unique_corr.get_corr_list().unique_corrs))

corr_df = pd.DataFrame(list_unique_corrs)
corr_df.to_csv("corr_df2.csv")

# %% [markdown]
# ### Model 1.a. Baseline Parameters
# First, we used the baseline parameters of sklearn.

# %%
corr_merged_df = pd.merge(corr_df, diagnose_df, on = "FILE_ID", how = "left")
corr_merged_df = corr_merged_df.dropna()

# %%
X = graph_merged_df.drop(["FILE_ID", "DX_GROUP", "DSM_IV_TR"], axis=1)
y = graph_merged_df["DX_GROUP"]

# Split Data into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize basic rf
rf = RandomForestClassifier(oob_score=True)
rf.fit(X_train, y_train)
rf_cross_val = cross_val_score(rf, X_train, y_train, cv=5)

# %%
print(f"This model has an OOB score of {rf.oob_score_}")
print(f"The mean cross validation score was {rf_cross_val.mean()}")
print(f"The standard deviation of our cross validation was {rf_cross_val.std()}")

# %% [markdown]
# ### Model 1.b. Hyperparameter Tuning

# %% [markdown]
# ## Model 2: Functional Connectivity, PCA

# %% [markdown]
# ### Prepare Data

# %% [markdown]
# ### Model 2.a. Baseline Parameters

# %% [markdown]
# ### Model 2.b. Hyperparameter Tuning

# %% [markdown]
# ## Model 3: Betweenness Centrality
#
# To employ a dimensionality reduction innate to functional connectivity data, with Model 3, we decided to focus on the numbers of connections each ROI has to other ROIs, i.e., betweenness centrality. Betweenness centrality is a graph theoretical measure which describes the number of "edges" (connections) a "node" (ROI) has. Although other graph theoretical measures such as global efficiency and clustering coefficient might also be of interest for our classifcation attempt, we decided to restrain our analysis due to time constraints.
#
# As threshholding the correlations between ROIs in order to create a binary graph can be accomplished in a somewhat arbitrary manner, we decided to get a more stable estimate by calculating the mean betweenness centrality based on proportional thresholds between percentile 70 and 90 in steps of 2.

# %% [markdown]
# ### Prepare Data

# %%
# Create class "GraphTheoryBetweenness" to calculate betweenness centrality.
# The idea is to first calculate the connectivity matrix and then based on this,
# continue with the betweenness centrality.
class GraphTheoryBetweenness:
    '''
        Parameters:
            - time_course_path: path to a 1D file containing timecourses of all relevant regions
              for one specific subject
            - correlation_kind: {"covariance", "correlation", "partial correlation", "tangent", "precision"}, 
              default="correlation"
              Kind of correlation to calcualte, takes same arguments as nilearn.connectome.ConnectivityMeasure()
            - thresh_percentile: int or list of ints for percentile(s) at which matrix is thresholded, default = 80
            - subject_ID: whether "FILE_ID" should be added to dict, default = True

        Returns: 
            - bet_cent_dict: Dictionnary with betweenness centrality for all ROIs and subject ID as key "FILE_ID"
    '''
    
    def __init__(self, thresh_percentile, correlation_kind, time_course_path, subject_ID=True):

        self.thresh_percentile = thresh_percentile
        self.correlation_kind = correlation_kind
        self.time_course_path = time_course_path
        self.subject_ID = subject_ID
        
    def corr_matrix(self):
        '''
        This function calculates a correlation matrix based on a 1D timeseries file.     
        
            Returns:
                - correlation_matrix: A correlation matrix in form of a 2D array 
        '''

        # Read in time courses as a dataframe
        timecourse_df = pd.read_csv(self.time_course_path, sep="\t")

        # Instantiate nilearn connectivity measure object
        correlation_measure  = connectome.ConnectivityMeasure(kind=self.correlation_kind)

        # Calculate partical correlations
        correlation_matrix = correlation_measure.fit_transform(
            np.array([timecourse_df]))[0]
    
        return(correlation_matrix)


    # A function that calculates betweenness centrality for a single subject
    def calculate_bet_centrality(self, subject_ID=True):
        '''
        This function calculates betweenness centrality for each ROI contained in
        a correlation matrix.
        
            Returns:
                - bet_cent: A dictionnary containing the betweenness centrality value for each ROI
        '''

        if type(self.thresh_percentile) == list:

            thresh_list = []

            for thresh_perc in self.thresh_percentile:

                # Define proportional threshold
                thresh = np.nanpercentile(self.corr_matrix(), thresh_perc)
            
                # Set edges to 1 or 0 depending on threshold
                mean_matrix_thresh = self.corr_matrix().copy()
                mean_matrix_thresh[mean_matrix_thresh < thresh] = 0
                mean_matrix_thresh[mean_matrix_thresh >= thresh] = 1
            
                # Create Graph
                G = nx.from_numpy_array(mean_matrix_thresh)
            
                # Calculate betweenness centrality
                bet_cent_thresh = nx.betweenness_centrality(G)

                thresh_list.append(bet_cent_thresh)
            
            bet_cent = dict(np.mean(pd.DataFrame(thresh_list), axis = 0))
            
        
        else:    
        
            # Define proportional threshold
            thresh = np.nanpercentile(self.corr_matrix(), self.thresh_percentile)
        
            # Set edges to 1 or 0 depending on threshold
            mean_matrix_thresh = self.corr_matrix().copy()
            mean_matrix_thresh[mean_matrix_thresh < thresh] = 0
            mean_matrix_thresh[mean_matrix_thresh >= thresh] = 1
        
            # Create Graph
            G = nx.from_numpy_array(mean_matrix_thresh)
        
            # Calculaate betweenness centrality
            bet_cent = nx.betweenness_centrality(G)
    
        if self.subject_ID:
            # Get "FILE_ID" from path and add it to dict
            subject_id = self.time_course_path.split("\\")[-1].split("_rois")[0]
            bet_cent["FILE_ID"] = subject_id   
            return(bet_cent)
        
        else:
            return(bet_cent)

# %%
# Here, we calculate betweenness centrality for all ROIs for all subjects

# Define thresholds we want to use
thresh_steps = np.arange(70, 91, 2).tolist()

# Create empty list
subj_dict_list = []

# Add dict for each subject to list
for path in subj_paths:
    graph_measure = GraphTheoryBetweenness(thresh_steps, "partial correlation", path) 
    subj_dict_list.append(graph_measure.calculate_bet_centrality())

# From list of dicts, create dataframe
graph_df = pd.DataFrame(subj_dict_list)

# %%
# This is our betweenness centrality dataframe
graph_df

# %%
graph_df.to_csv("graph_df.csv", index = False)

# %% [markdown]
# ### Model 3.a. Baseline Parameters

# %%
On server

# %%
# We read in the phenotype dataframe and create a new df with only diagnoses
pheno_df = pd.read_csv("Phenotypic_V1_0b_preprocessed1.csv", index_col = 0)
diagnose_df = pheno_df.loc[:,["FILE_ID", "DX_GROUP", "DSM_IV_TR"]]

# We merge on file name
graph_merged_df = pd.merge(graph_df, diagnose_df, on = "FILE_ID", how = "left")
graph_merged_df = graph_merged_df.dropna()

# %%
X = graph_merged_df.drop(["FILE_ID", "DX_GROUP", "DSM_IV_TR"], axis=1)
y = graph_merged_df["DX_GROUP"]

# Split Data into test and train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize basic rf
rf = RandomForestClassifier(oob_score=True)

rf.fit(X_train, y_train)
rf_cross_val = cross_val_score(rf, X_train, y_train, cv=5)

# %%
print(f"This model has an OOB score of {rf.oob_score_}")
print(f"The mean cross validation score was {rf_cross_val.mean()}")
print(f"The standard deviation of our cross validation was {rf_cross_val.std()}")
# Out:
# This model has an OOB score of 0.5226537216828478
# The mean cross validation score was 0.5371754523996853
# The standard deviation of our cross validation was 0.03495660489716523

# %% [markdown]
# ### Model 3.b. Hyperparameter Tuning

# %% [markdown]
# ## Old functions I need to make object-oriented

# %%
# Define function which get list of unique correlations for one subject
def get_corr_list(path, kind):
    
    '''
    Inputs: path, 
    - path: path to the extracted timecourses for one subject.
    - kind: {“covariance”, “correlation”, “partial correlation”, “tangent”, “precision”}, 
      default=’covariance’
      kind of correlation, takes all arguments nilearn.connectome.ConnectivityMeasure()
      
    Outputs: unique_corrs, connectivity_matrix
    - unique corrs: dictionnary with unique correlations between timecourses,
      keys corresponding to correlation of two timeseries 
      e.g.: key '0x4' corresponds to correlation of regions 0 and 4.
    - connectivity matrix: connectivity matrix for all timeseries for one subjects.
      can be used plotted with nilearn.plotting.plot_matrix()
    
    '''

    # read the file into a DataFrame
    df = pd.read_csv(path, sep="\t")
    df = np.array(df)
    
    # calculate corr matrix for DataFrame (all rois)
    correlation_measure = connectome.ConnectivityMeasure(
        kind=kind
    )
    
    connectivity_matrix = correlation_measure.fit_transform([df])[0]
    corrs = pd.DataFrame(connectivity_matrix)

    # create index with only unique combinations of row x column
    # this ensures we get an index which only gets us the "lower half"
    # of the correlation matrix
    rois_numbers = np.linspace(0, (len(corrs)-1), len(corrs), dtype = "int")
    comb_ind = [comb for comb in combinations(rois_numbers, 2)]

    # use new index to select only the unique combinations from our DataFrame
    # we save this as a dictionnary with the combination of values as keys
    # I.e., correlation of region 1 and region 4 is called "1x4"
    unique_corrs = {}
    for ind in comb_ind:
       unique_corrs[f"{ind[0]}x{ind[1]}"] = corrs.iloc[ind]

    # We add the name of the file as "ID" to the dictionnary.
    # This allows us to later identify the subjects when we create our
    # DataFrame with all our subjects
    unique_corrs["ID"] = path.split("/")[-1]

    return(unique_corrs, connectivity_matrix)

# %% [markdown]
# The below cell takes approximately ?? minutes

# %%
# Create DataFrame with all subjects
list_unique_corrs = []
for path in subj_paths:
    list_unique_corrs.append(get_corr_list(path, kind = "partial correlation")[0])

complete_df = pd.DataFrame(list_unique_corrs)
complete_df.to_csv("partial_corr_df.csv")

# %%
complete_df.to_csv("partial_corr_df.csv")

# %%
complete_df
# Out:
#           0x1       0x2       0x3       0x4       0x5       0x6       0x7
# 0    0.007605 -0.093767  0.025952 -0.004101  0.029709 -0.024893 -0.056791  \
# 1    0.020877 -0.055024  0.005723 -0.026987 -0.019686  0.032149 -0.027109
# 2   -0.021543 -0.002342 -0.077224  0.010351 -0.008699 -0.061259 -0.036689
# 3   -0.087209 -0.013003  0.019987  0.007853  0.070366 -0.021554  0.001785
# 4    0.011371  0.001493 -0.025405 -0.004347 -0.024392 -0.037107 -0.011480
# ..        ...       ...       ...       ...       ...       ...       ...
# 879  0.013888 -0.038484  0.008113  0.008713 -0.028483 -0.034524  0.006456
# 880  0.015597  0.047033 -0.028770 -0.025831  0.009842 -0.099223  0.023746
# 881  0.057704 -0.040731  0.036248 -0.028012 -0.017422  0.040367 -0.013773
# 882 -0.022718  0.013849  0.031890  0.062709  0.005144 -0.019952 -0.065440
# 883 -0.054805 -0.026919  0.010378 -0.034736 -0.032979  0.027343 -0.004700
#
#           0x8       0x9      0x10  ...   195x197   195x198   195x199
# 0   -0.067321 -0.047638  0.032802  ... -0.010210 -0.002754  0.012114  \
# 1   -0.013659  0.026269 -0.023326  ... -0.000000  0.012072 -0.023838
# 2   -0.016293 -0.000000  0.042201  ... -0.000000 -0.168892  0.026266
# 3   -0.080408  0.013837 -0.025278  ... -0.008020  0.076996  0.090542
# 4   -0.044027 -0.004783 -0.009429  ...  0.000737  0.022216  0.044547
# ..        ...       ...       ...  ...       ...       ...       ...
# 879 -0.012639 -0.022639  0.012105  ...  0.008112  0.042715 -0.021487
# 880  0.005844  0.016276  0.007632  ...  0.000456 -0.036027 -0.006571
# 881 -0.008708 -0.029883  0.026940  ... -0.040245 -0.028593 -0.023434
# 882 -0.000002 -0.011738 -0.001780  ...  0.000452  0.056748 -0.067353
# 883 -0.036552  0.009519  0.017966  ... -0.015527  0.108154 -0.011045
#
#       196x197   196x198   196x199   197x198   197x199   198x199
# 0    0.029563  0.084258  0.021982  0.031459  0.046450  0.032715  \
# 1   -0.000000 -0.016615  0.012068 -0.000000  0.000000  0.112876
# 2   -0.000000  0.054605  0.034935  0.000000  0.000000 -0.085090
# 3   -0.003828  0.040650 -0.056931  0.000223 -0.013338  0.026678
# 4   -0.007328 -0.068902 -0.062551 -0.013311 -0.007835 -0.044507
# ..        ...       ...       ...       ...       ...       ...
# 879  0.012022  0.006185  0.008967 -0.018410  0.055779 -0.024578
# 880  0.007715 -0.017228  0.054851  0.004269  0.017597  0.067953
# 881 -0.007964 -0.009148  0.003982 -0.004194  0.004152  0.038866
# 882 -0.001106  0.042089 -0.001142  0.000731 -0.000946  0.005785
# 883  0.000873  0.026364 -0.013097 -0.067531  0.018364  0.010148
#
#                                          ID
# 0    rois_cc200\CMU_a_0050649_rois_cc200.1D
# 1    rois_cc200\CMU_a_0050653_rois_cc200.1D
# 2    rois_cc200\CMU_b_0050651_rois_cc200.1D
# 3    rois_cc200\CMU_b_0050657_rois_cc200.1D
# 4    rois_cc200\CMU_b_0050669_rois_cc200.1D
# ..                                      ...
# 879   rois_cc200\Yale_0050624_rois_cc200.1D
# 880   rois_cc200\Yale_0050625_rois_cc200.1D
# 881   rois_cc200\Yale_0050626_rois_cc200.1D
# 882   rois_cc200\Yale_0050627_rois_cc200.1D
# 883   rois_cc200\Yale_0050628_rois_cc200.1D
#
# [884 rows x 19901 columns]

# %% [markdown]
# ## Discussion
# We were able to predict ASD diagnosis with ??% accuracy in the test data. While this points to general differences in functional connectivity between people with ASD and neurotypicals, our results cannot offer evidence for a potential diagnostic tool based on functional connectivity. However, we left several avenues unexplored, which may constitute starting points for more comprehensive analyses and comparisons to obtain both higher classification accuracies but also inferences about the neural correlates of ASD. Utilizing different graph theoretical measures might ...

# %% [markdown]
# ## References:
#
# Craddock, R. C., Benhajali, B., Chu, C., Chouinard, C., Evans, E., Jakab, J., Khundrakpam, K., Lewis, L., Li, L., Milham, M., Yan, Y. & Bellec, B. (2013). The Neuro Bureau Preprocessing Initiative: open sharing of preprocessed neuroimaging data and derivatives. *Frontiers in Neuroinformatics, 7*. https://doi.org/10.3389/conf.fninf.2013.09.00041
#
# Craddock, R. C., James, G., Holtzheimer, P. E., Hu, X. P. & Mayberg, H. S. (2011). A whole brain fMRI atlas generated via spatially constrained spectral clustering. *Human Brain Mapping, 33*(8), 1914–1928. https://doi.org/10.1002/hbm.21333
#
# Ilioska, I., Oldehinkel, M., Llera, A., Chopra, S., Looden, T., Chauvin, R., Van Rooij, D., Floris, D. L., Tillmann, J., Moessnang, C., Banaschewski, T., Holt, R. J., Loth, E., Charman, T., Murphy, D. G., Ecker, C., Mennes, M., Beckmann, C. F., Fornito, A. & Buitelaar, J. K. (2023). Connectome-wide Mega-analysis Reveals Robust Patterns of Atypical Functional Connectivity in Autism. *Biological Psychiatry, 94*(1), 29–39. https://doi.org/10.1016/j.biopsych.2022.12.018
#
# Lord, C., Brugha, T. S., Charman, T., Cusack, J., Dumas, G., Frazier, T., Jones, E. J. H., Jones, R. M., Pickles, A., State, M. W., Taylor, J. L. & Veenstra-VanderWeele, J. (2020). Autism spectrum disorder. *Nature Reviews. Disease Primers, 6*(1). https://doi.org/10.1038/s41572-019-0138-4
